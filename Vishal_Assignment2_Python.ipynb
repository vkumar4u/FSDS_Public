# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# True and False
# Programmatically, False is referred as 0 while True is referred as 1
#
# 2. What are the three different types of Boolean operators?
#
# and
# or
# not
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
# a = 10
# b = 20
# a == 10 and b == 20 returns True
# a == 10 and b == 30 returns False
# a == 10 or b == 30 returns True
# a == 20 or b == 30 returns False
# not a == 20 and not b == 20 returns False
# not a == 20 or not b == 20 returns True
#
#
#
# 4. What are the values of the following expressions?
# (5 > 4) and (3 == 5)
#     False
# not (5 > 4)
#     False
# (5 > 4) or (3 == 5)
#     True
# not ((5 > 4) or (3 == 5))
#     False
# (True and True) and (True == False)
#     False
# (not False) or (not True)
#     True
#
#
#
# 5. What are the six comparison operators?
# > Greater than
# >= Greater than and Equal to
# < Less than
# <= Less Than and Equal to
# == Equal to
# != Not equal to
#
# 6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
# Single equal sign (=) is used for assignement values while double equal signs (==) are used for comparison values
#  var1 = 4 # This is assignment operation
#  if var1 == 4: # This is comparison operator
#      print ("Value is 4")
# In above example, we used = sign to assign value 4 to variable var1. Later, we compared the value of var1 using == operator
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
#     print('eggs')
# if spam > 5:
#     print('bacon')
# else:
#     print('ham')
# print('spam')
# print('spam')
#
# First block starts from first if statement (if spam == 10)
# Second block starts from second if statement (if spam > 5)
# Third blocks starts from else statement (else)
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# spam = 1
# if spam == 1:
#     print ("Hello")
# elif spam == 2:
#     print ("Howdy")
# else:
#     print ("Greetings")
#
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
# Ctrl + C
#
# 10. How can you tell the difference between break and continue?
#
# 'break' breaks the flow and come out of loop while with continue, control is passed back to the beginning of the loop without executing the preeceding code
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
# range with single parameter executes the code repeatedly till the listed count - 1
# range with first 2 parameters signifies start position and end position -1 loop
# range with 3 parameters signifies start position, end - 1 position and step counts
#
# In above example, all range function in the for loop will provide same result
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
# for var1 in range(1,11):
#     print (var1)
#
#
#  var1 = 1
# while var1 <= 10:
#     print (var1)
#     var1 += 1
#
#
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
#
# from spam import bacon
