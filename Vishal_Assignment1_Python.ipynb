# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *
#         EXPRESSION
# 'hello'
#         VALUES
# -87.8
#         VALUES
# -
#         EXPRESSION
# /
#         EXPRESSION
# +
#         EXPRESSION
# 6
#         VALUES
#
#
#
#
# 2. What is the difference between string and variable?
#
# String is alphanumeric values which are used for any programing requirement. Variables are temporary placeholders which are stored in memory and is used to contain values temporarily for our programming requirement
#
#
#
#
#
#
# 3. Describe three different data types.
# STR - STR is used for storing any alphanumeric data
# INT - INT is used for storing numerical value and for calculating any arithmatic calculations
# BOOLEAN - BOOLEAN is used for identifying answers in terms of TRUE or FALSE output
#
#
#
#
#
# 4. What is an expression made up of? What do all expressions do?
# Expressions are made up of mathematcial operators such as multiple, divide, subtract, sum, MOD etc. of different values. It is used to perform any arithmatic calculations for our programing needs
#
#
#
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# EXPTRESSION are mathematical operators while assigment statement is 'assigmnent of some values to a variable temporarily'
#
#
#
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# 22
#
#
#
#
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
#         spamspamspam
# 'spam' * 3
#         spamspamspam
#
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
# As eggs is not a system defined function, so its a valid variable name while 100 is starting with numberic value, hence it is an invalid variable since Python does not allow variable name starting with number
#
#
#
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# For int, we should use int()
# For Float-Point number, we can use float()
# For String type value, we can use str()
#
#
#
#
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# As the statement above is trying to concatenate string and int data together, so the statement will result in an error for typecasting. To fix the issue, we can use str(90) instead of 90
